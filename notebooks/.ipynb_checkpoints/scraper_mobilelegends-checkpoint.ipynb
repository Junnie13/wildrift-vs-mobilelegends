# %% [markdown]
# ## 1. Get the data from Google PlayStore

# %%
from google_play_scraper import app, Sort, reviews_all, reviews
import pandas as pd
import numpy as np

# %%
# reviews_all() method extracts ALL of the reviews from google playstore, the others are the parameters for the reviews_all() method (more here: https://pypi.org/project/google-play-scraper/)
google_reviews, continuation_token = reviews(
        "com.mobile.legends", # https://play.google.com/store/apps/details?id=com.mobile.legends&hl=en&pli=1
        lang = 'en', # defaults to 'en'
        country = 'us', # defaults to 'us'
        sort = Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
        count = 2000 # default = 100
    )

result, _ = reviews(
    'com.mobile.legends',
    continuation_token= continuation_token # defaults to None (load from the beginning)
)

# dataframe that takes all of the reviews from google play
google_df = pd.DataFrame(np.array(google_reviews), columns=['review'])
google_df2 = google_df.join(pd.DataFrame(google_df.pop('review').tolist()))

google_df2
# Out:
#                                  reviewId              userName  \
# 0    60aa12f5-d203-48d4-95bb-5303a8666644       Koji roy Buatis
# 1    b82fc220-1300-49cb-96b6-6cc9931336cf      George hortelano
# 2    44077438-f6b9-4b9f-b68d-fed741feeff3    Venchito Dalumingo
# 3    753d2e8c-b188-4fc3-9a96-2c11a1605aa1        Michael Varnal
# 4    5d902aa8-c57a-4097-8907-197d0bdc8667         Myra Taguinod
# ..                                    ...                   ...
# 194  d899be33-c441-4b8d-87a2-45ae7678a17e         Sanjay Sanjay
# 195  f47fd5b0-1e68-411a-b034-f244f2884c8a          Ameer Haiqal
# 196  251cb66e-5cb5-4c07-98e9-ea723be37beb  Johnfredierick Duran
# 197  74f791e2-f0de-4536-8f23-ba7c6ea8985c       Krizzia tuscano
# 198  843aa036-e240-479f-b04d-3a7064e06738           Ahmad Hafiz
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a/ACg8oc...
# 2    https://play-lh.googleusercontent.com/a/ACg8oc...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 194  https://play-lh.googleusercontent.com/a/ACg8oc...
# 195  https://play-lh.googleusercontent.com/a-/ALV-U...
# 196  https://play-lh.googleusercontent.com/a/ACg8oc...
# 197  https://play-lh.googleusercontent.com/a/ACg8oc...
# 198  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0                                     Because it's fun      5              0
# 1                              It is really impressive      5              0
# 2    This game is very great and i hope every one i...      5              0
# 3                                            Best game      5              0
# 4                                 Mga b*b* pinapakampe      1              0
# ..                                                 ...    ...            ...
# 194  Absolutely marvellous game. 🎉 Ultimate battle,...      5              0
# 195  Moonton jahanam bagi dark sistem nak naik rank...      1              0
# 196                                            Maganda      5              0
# 197                                               Nice      1              0
# 198                                               good      5              0
#
#     reviewCreatedVersion                  at replyContent repliedAt  \
# 0            1.8.79.9552 2024-05-29 16:48:07         None      None
# 1            1.8.79.9552 2024-05-29 16:47:22         None      None
# 2            1.8.79.9552 2024-05-29 16:47:19         None      None
# 3            1.8.79.9552 2024-05-29 16:46:53         None      None
# 4            1.8.79.9552 2024-05-29 16:44:51         None      None
# ..                   ...                 ...          ...       ...
# 194          1.8.79.9552 2024-05-29 13:49:34         None      None
# 195                 None 2024-05-29 13:47:06         None      None
# 196          1.8.79.9552 2024-05-29 13:45:20         None      None
# 197          1.8.79.9552 2024-05-29 13:44:29         None      None
# 198          1.8.79.9552 2024-05-29 13:41:33         None      None
#
#       appVersion
# 0    1.8.79.9552
# 1    1.8.79.9552
# 2    1.8.79.9552
# 3    1.8.79.9552
# 4    1.8.79.9552
# ..           ...
# 194  1.8.79.9552
# 195         None
# 196  1.8.79.9552
# 197  1.8.79.9552
# 198  1.8.79.9552
#
# [199 rows x 11 columns]

# %%
# def fetch_all_reviews(app_id, lang='en', country='us', sort=Sort.NEWEST, batch_size=2000):
#     all_reviews = []
#     continuation_token = None

#     while True:
#         google_reviews, continuation_token = reviews(
#             app_id,
#             lang=lang,
#             country=country,
#             sort=sort,
#             count=batch_size,
#             continuation_token=continuation_token
#         )
#         all_reviews.extend(google_reviews)
        
#         # Break the loop if no more reviews are available
#         if continuation_token is None:
#             break
    
#     return all_reviews

# # Fetch all reviews for the specified app
# app_id = "com.mobile.legends"
# all_google_reviews = fetch_all_reviews(app_id, batch_size=2000)

# # Convert the list of reviews into a DataFrame
# google_df = pd.DataFrame(np.array(all_google_reviews), columns=['review'])
# google_df2 = google_df.join(pd.DataFrame(google_df.pop('review').tolist()))

# # Display the resulting DataFrame
# print(google_df2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 24>()
#      22 # Fetch all reviews for the specified app
#      23 app_id = "com.mobile.legends"
# ---> 24 all_google_reviews = fetch_all_reviews(app_id, batch_size=2000)
#      26 # Convert the list of reviews into a DataFrame
#      27 google_df = pd.DataFrame(np.array(all_google_reviews), columns=['review'])
#
# Input In [4], in fetch_all_reviews(app_id, lang, country, sort, batch_size)
#       3 continuation_token = None
#       5 while True:
# ----> 6     google_reviews, continuation_token = reviews(
#       7         app_id,
#       8         lang=lang,
#       9         country=country,
#      10         sort=sort,
#      11         count=batch_size,
#      12         continuation_token=continuation_token
#      13     )
#      14     all_reviews.extend(google_reviews)
#      16     # Break the loop if no more reviews are available
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\features\reviews.py:76, in reviews(app_id, lang, country, sort, count, filter_score_with, filter_device_with, continuation_token)
#      73 sort = sort.value
#      75 if continuation_token is not None:
# ---> 76     token = continuation_token.token
#      78     if token is None:
#      79         return (
#      80             [],
#      81             continuation_token,
#      82         )
#
# KeyboardInterrupt:
