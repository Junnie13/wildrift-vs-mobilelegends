# %% [markdown]
# ## 1. Get the data from Google PlayStore

# %%
from google_play_scraper import app, Sort, reviews_all, reviews
import pandas as pd
import numpy as np

# %%
# reviews_all() method extracts ALL of the reviews from google playstore, the others are the parameters for the reviews_all() method (more here: https://pypi.org/project/google-play-scraper/)
google_reviews, continuation_token = reviews(
        "com.mobile.legends", # https://play.google.com/store/apps/details?id=com.mobile.legends&hl=en&pli=1
        lang = 'en', # defaults to 'en'
        country = 'us', # defaults to 'us'
        sort = Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
        count = 2000 # default = 100
    )

result, _ = reviews(
    'com.mobile.legends',
    continuation_token= continuation_token # defaults to None (load from the beginning)
)

# dataframe that takes all of the reviews from google play
google_df = pd.DataFrame(np.array(google_reviews), columns=['review'])
google_df2 = google_df.join(pd.DataFrame(google_df.pop('review').tolist()))

google_df2
# Out:
#                                  reviewId                 userName  \
# 0    716b5519-bb3c-43a2-a001-8ccddb6b477d             BR Kmenglaor
# 1    bccf8c02-bc69-4827-87c6-e39443bf8ec6      Abdul Hamza Mingkat
# 2    81e4433f-9f5a-436e-9854-8afdd85068e8      John andrei Occiano
# 3    68180187-424e-42bf-93e5-b6246ea846ad             Miles Garcia
# 4    d5a9243d-ff3b-4376-a294-dfede78e1436         Min May Lol Lite
# ..                                    ...                      ...
# 592  5fb572dc-5c63-4f01-a8f4-8cf04222178a            billy clarito
# 593  78a23cfc-bc1f-4cb2-bf50-23d1431d05e4  Jaztine Andales Mendoza
# 594  4aede110-b9ff-468a-a7f5-214f1298da18            Nighel Abanez
# 595  5f5f523a-92ba-4efb-8b58-b3d72d09b4e3                   Gvx Fs
# 596  bec01c01-d140-4b42-8fca-2cd14226badf           Jaylord Genabe
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a/ACg8oc...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 592  https://play-lh.googleusercontent.com/a/ACg8oc...
# 593  https://play-lh.googleusercontent.com/a/ACg8oc...
# 594  https://play-lh.googleusercontent.com/a/ACg8oc...
# 595  https://play-lh.googleusercontent.com/a/ACg8oc...
# 596  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Game mobilegend luv bahk lg man ten all bro ki...      5              0
# 1                  Bubo mo magbigay ng kasama moonton!      1              0
# 2    I have a decent internet network and i dont kn...      1              0
# 3    My internet connection is fine but I always ge...      1              0
# 4                                    @ZAW MOBLE King:😎      5              0
# ..                                                 ...    ...            ...
# 592                                      Madameng pepe      5              0
# 593  I love the game, really the characters the map...      4              0
# 594              Si monton hindi nagbibigay ng diamond      1              0
# 595            bagus sekali walapun rank saya legend 5      5              0
# 596              Good experience to improve your skill      5              0
#
#     reviewCreatedVersion                  at replyContent repliedAt  \
# 0                   None 2024-05-29 20:53:43         None      None
# 1            1.8.79.9552 2024-05-29 20:53:21         None      None
# 2            1.8.79.9552 2024-05-29 20:52:15         None      None
# 3            1.8.80.9553 2024-05-29 20:51:07         None      None
# 4            1.8.79.9552 2024-05-29 20:50:18         None      None
# ..                   ...                 ...          ...       ...
# 592                 None 2024-05-29 11:57:30         None      None
# 593          1.8.79.9552 2024-05-29 11:57:10         None      None
# 594          1.8.79.9552 2024-05-29 11:56:27         None      None
# 595          1.8.79.9552 2024-05-29 11:56:23         None      None
# 596          1.8.79.9552 2024-05-29 11:54:36         None      None
#
#       appVersion
# 0           None
# 1    1.8.79.9552
# 2    1.8.79.9552
# 3    1.8.80.9553
# 4    1.8.79.9552
# ..           ...
# 592         None
# 593  1.8.79.9552
# 594  1.8.79.9552
# 595  1.8.79.9552
# 596  1.8.79.9552
#
# [597 rows x 11 columns]

# %%
# def fetch_all_reviews(app_id, lang='en', country='us', sort=Sort.NEWEST, batch_size=2000):
#     all_reviews = []
#     continuation_token = None

#     while True:
#         google_reviews, continuation_token = reviews(
#             app_id,
#             lang=lang,
#             country=country,
#             sort=sort,
#             count=batch_size,
#             continuation_token=continuation_token
#         )
#         all_reviews.extend(google_reviews)
        
#         # Break the loop if no more reviews are available
#         if continuation_token is None:
#             break
    
#     return all_reviews

# # Fetch all reviews for the specified app
# app_id = "com.mobile.legends"
# all_google_reviews = fetch_all_reviews(app_id, batch_size=2000)

# # Convert the list of reviews into a DataFrame
# google_df = pd.DataFrame(np.array(all_google_reviews), columns=['review'])
# google_df2 = google_df.join(pd.DataFrame(google_df.pop('review').tolist()))

# # Display the resulting DataFrame
# print(google_df2)
